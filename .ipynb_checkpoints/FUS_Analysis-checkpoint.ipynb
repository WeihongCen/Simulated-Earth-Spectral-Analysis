# %% [markdown]
# # Time Series Analysis of Shortwave Upward Flux

# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr 
import pandas as pd
#from netCDF4 import Dataset
#from mpl_toolkits.basemap import Basemap

# %% [markdown]
# NetCDF files

# %%
simulated_Earth_Folder = "C:/Users/cenwe/Downloads/Programming/Python/simulated_Earth/"
aqua_folder = "C:/Users/cenwe/Downloads/Programming/Python/simulated_Earth/Water/"
land_folder = "C:/Users/cenwe/Downloads/Programming/Python/simulated_Earth/Land/"

data1 = xr.open_dataset(simulated_Earth_Folder + "jan.nc")
data2 = xr.open_dataset(simulated_Earth_Folder + "feb.nc")
data3 = xr.open_dataset(simulated_Earth_Folder + "mar.nc")
data4 = xr.open_dataset(simulated_Earth_Folder + "apr.nc")
data5 = xr.open_dataset(simulated_Earth_Folder + "may.nc")
data6 = xr.open_dataset(simulated_Earth_Folder + "jun.nc")
data7 = xr.open_dataset(simulated_Earth_Folder + "jul.nc")

a_data1 = xr.open_dataset(aqua_folder + "a_jan.nc")
a_data2 = xr.open_dataset(aqua_folder + "a_feb.nc")
a_data3 = xr.open_dataset(aqua_folder + "a_mar.nc")
a_data4 = xr.open_dataset(aqua_folder + "a_apr.nc")
a_data5 = xr.open_dataset(aqua_folder + "a_may.nc")
a_data6 = xr.open_dataset(aqua_folder + "a_jun.nc")

l_data1 = xr.open_dataset(land_folder + "l_jan.nc")
l_data2 = xr.open_dataset(land_folder + "l_feb.nc")
l_data3 = xr.open_dataset(land_folder + "l_mar.nc")
l_data4 = xr.open_dataset(land_folder + "l_apr.nc")
l_data5 = xr.open_dataset(land_folder + "l_may.nc")
l_data6 = xr.open_dataset(land_folder + "l_jun.nc")

# %%
FUS1 = data1.FUS
FUS2 = data2.FUS
FUS3 = data3.FUS
FUS4 = data4.FUS
FUS5 = data5.FUS
FUS6 = data6.FUS
FUS7 = data7.FUS

a_FUS1 = a_data1.FUS
a_FUS2 = a_data2.FUS
a_FUS3 = a_data3.FUS
a_FUS4 = a_data4.FUS
a_FUS5 = a_data5.FUS
a_FUS6 = a_data6.FUS

l_FUS1 = l_data1.FUS
l_FUS2 = l_data2.FUS
l_FUS3 = l_data3.FUS
l_FUS4 = l_data4.FUS
l_FUS5 = l_data5.FUS
l_FUS6 = l_data6.FUS

l_FUL1 = l_data1.FUL
l_FUL2 = l_data2.FUL
l_FUL3 = l_data3.FUL
l_FUL4 = l_data4.FUL
l_FUL5 = l_data5.FUL
l_FUL6 = l_data6.FUL

# %%
FUSGraph = a_FUS1.isel(time = 0, ilev = 0)
plt.figure(figsize=(8,4))
FUSGraph.plot(robust = True)
plt.grid(True)

# %% [markdown]
# ## Daily Average Radiative Flux

# %% [raw]
# dayArray = []
# hours = 48
#
# for t in range(hours):
#     dayArray.append(FUS1.isel(time = t, ilev = 0).mean())
#
# plt.figure(figsize=(12,6))
# plt.plot(dayArray)
# plt.title('Average Radiative Flux 2015-01-01 to 2015-02-01')
# plt.ylabel('Shortwave Upward Flux (W/m2)')
# plt.xlabel('Date')
# plt.grid(True)
# plt.xticks(np.arange(0, 60, 12), ['01/01', '01/02', '01/03', '01/04', '01/05'])

# %% [markdown]
# ## Monthly Average Radiative Flux

# %% [markdown]
# The average calculated includes radiative flux from regions not photographed by DSCOVR
# <br>
# An average of 1784 out of 3312 coordinates at any time-period have radiative flux data

# %% [raw]
# janArray = []
# hours = 360
#
# for t in range(hours):
#     janArray.append(FUS1.isel(time = t, ilev = 0).mean())
#
# plt.figure(figsize=(12,6))
# plt.plot(janArray)
# plt.title('Average Radiative Flux 2015-01-01 to 2015-02-01')
# plt.ylabel('Shortwave Upward Flux (W/m2)')
# plt.xlabel('Date')
# plt.grid(True)
# plt.xticks(np.arange(0, 384, 60), ['01/01', '01/06', '01/11', '01/16', '01/21', '01/26', '01/31'])

# %% [markdown]
# ## 2015 Average Radiative Flux

# %%
def appendAll(inputArray, inputList):
    for t in range(len(inputList)):
        inputArray.append(inputList.isel(time = t, ilev = 0).mean())
    return inputArray

# %%
annualArrayFUS = []

#A lot of repetitive code for every month of the year
annualArrayFUS = appendAll(annualArrayFUS, FUS1)
annualArrayFUS = appendAll(annualArrayFUS, FUS2)
annualArrayFUS = appendAll(annualArrayFUS, FUS3)
annualArrayFUS = appendAll(annualArrayFUS, FUS4)
annualArrayFUS = appendAll(annualArrayFUS, FUS5)
annualArrayFUS = appendAll(annualArrayFUS, FUS6)
annualArrayFUS = appendAll(annualArrayFUS, FUS7)

plt.figure(figsize=(12,6))
plt.plot(annualArrayFUS, label = 'average FUS')
plt.title('Average Radiative Flux 2015 (Shortwave Upward Flux)')
plt.ylabel('Shortwave Upward Flux (W/m2)')
plt.xlabel('Month')
plt.grid(True)
plt.xticks(np.arange(0, 2880, 360), ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug'])
#Get moving average
FUSdf = pd.DataFrame(annualArrayFUS)
movingMean = FUSdf.rolling(48).mean()
shiftedmm = movingMean.shift(-24)
plt.plot(shiftedmm, label = 'moving average')
plt.legend();

# %%
a_annualArrayFUS = []

a_annualArrayFUS = appendAll(a_annualArrayFUS, a_FUS1)
a_annualArrayFUS = appendAll(a_annualArrayFUS, a_FUS2)
a_annualArrayFUS = appendAll(a_annualArrayFUS, a_FUS3)
a_annualArrayFUS = appendAll(a_annualArrayFUS, a_FUS4)
a_annualArrayFUS = appendAll(a_annualArrayFUS, a_FUS5)
a_annualArrayFUS = appendAll(a_annualArrayFUS, a_FUS6)

plt.figure(figsize=(12,6))
plt.plot(a_annualArrayFUS, label = 'average FUS')
plt.title('Ocean (Shortwave Upward Flux)')
plt.ylabel('Shortwave Upward Flux (W/m2)')
plt.xlabel('Month')
plt.grid(True)
plt.xticks(np.arange(0, 2880, 360), ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug'])
#Get moving average
FUSdf = pd.DataFrame(a_annualArrayFUS)
movingMean = FUSdf.rolling(48).mean()
shiftedmm = movingMean.shift(-24)
plt.plot(shiftedmm, label = 'moving average')
plt.legend();

# %%
l_annualArrayFUS = []

l_annualArrayFUS = appendAll(l_annualArrayFUS, l_FUS1)
l_annualArrayFUS = appendAll(l_annualArrayFUS, l_FUS2)
l_annualArrayFUS = appendAll(l_annualArrayFUS, l_FUS3)
l_annualArrayFUS = appendAll(l_annualArrayFUS, l_FUS4)
l_annualArrayFUS = appendAll(l_annualArrayFUS, l_FUS5)
l_annualArrayFUS = appendAll(l_annualArrayFUS, l_FUS6)

plt.figure(figsize=(12,6))
plt.plot(l_annualArrayFUS, label = 'average FUS')
plt.title('Land (Shortwave Upward Flux)')
plt.ylabel('Shortwave Upward Flux (W/m2)')
plt.xlabel('Month')
plt.grid(True)
plt.xticks(np.arange(0, 2880, 360), ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug']);

# %%
l_annualArrayFUL = []

l_annualArrayFUL = appendAll(l_annualArrayFUL, l_FUL1)
l_annualArrayFUL = appendAll(l_annualArrayFUL, l_FUL2)
l_annualArrayFUL = appendAll(l_annualArrayFUL, l_FUL3)
l_annualArrayFUL = appendAll(l_annualArrayFUL, l_FUL4)
l_annualArrayFUL = appendAll(l_annualArrayFUL, l_FUL5)
l_annualArrayFUL = appendAll(l_annualArrayFUL, l_FUL6)

plt.figure(figsize=(12,6))
plt.plot(l_annualArrayFUL, label = 'average FUS')
plt.title('Average Radiative Flux 2015 (Longwave Upward Flux)')
plt.ylabel('Longwave Upward Flux (W/m2)')
plt.xlabel('Month')
plt.grid(True)
plt.xticks(np.arange(0, 2880, 360), ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug']);

# %% [markdown]
# ## Fourier Power Spectrum Analysis

# %%
import random
import matplotlib
from matplotlib.ticker import ScalarFormatter
import statistics 
from statistics import mode

# %% [markdown]
# #### Reset

# %%
def reset(fftInput):
    fftOutput = np.array(fftInput) #Reset to default & convert list to numpy arrays
    return fftOutput

# %% [markdown]
# #### Scenario 1: Unevenly spaced time series

# %%
def scenario1(fftInput, chance):
    for i in range(len(fftInput)):
        if random.random() < chance:
            fftInput[i] = fftInput[i-1]
    return fftInput

# %% [markdown]
# #### Scenario 2: Few time series samples

# %%
def scenario2(fftInput, dailydp):
    fftInput = np.array(annualArrayFUS)
    counter = 0
    for i in range(len(fftInput)):
        if counter < 12 / dailydp:
            fftInput[i] = fftInput[i-1]
            counter = counter + 1
        else:
            counter = 0
    return fftInput

# %% [markdown]
# #### Scenario 3: Random fluctuations

# %%
def scenario3(fftInput, chance, magnitude):
    fluctuation_chance = chance
    fluctuation_magnitude = magnitude
    randomNum = random.random()
    for i in range(len(fftInput)):
        if randomNum < fluctuation_chance/2:
            fftInput[i] = fftInput[i] + random.random()*fluctuation_magnitude
        elif randomNum > 1 - fluctuation_chance/2:
            fftInput[i] = fftInput[i] - random.random()*fluctuation_magnitude
    return fftInput

# %% [markdown]
# #### Scenario 4: Sections averaged for exposure time

# %%
def scenario4(fftInput, length):
    tempMean = 0
    counter = 0

    for i in range(len(fftInput)):
        counter += 1
        if counter >= length:
            counter -= length
            for j in range(int(length)):
                try:
                    tempMean = tempMean + fftInput[i + j]
                except:
                    pass
            
            tempMean = tempMean / length
            
            for x in range(int(length)):
                try:
                    fftInput[i + x] = tempMean
                except:
                    pass
            tempMean = 0
    return fftInput

# %% [markdown]
# #### Get graph parameters

# %%
def findFourier(fftInput):
    fourierTransform = np.fft.fft(fftInput)
    fourierTransform = fourierTransform[0:int(len(fftInput)/2)]
    powerSpectrum = fourierTransform
    frequency = np.arange(0, len(fftInput)/2)
    return powerSpectrum, frequency

# %% [markdown]
# #### Fourier transform graph

# %%
fftInput = reset(annualArrayFUS)
fftInput = scenario4(fftInput, 1)
powerSpectrum, frequency = findFourier(fftInput)

start = 1
end = 2520
dpInterval = 2

fig, ax1 = plt.subplots(figsize=(14,6))
ax1.plot(1/frequency[start:end]*len(fftInput)*dpInterval, abs(powerSpectrum)[start:end])
ax1.set_yscale('log')
ax1.set_xscale('log')
ax1.grid(True)
ax1.set_xticks([3, 6, 8, 12, 24, 120])
ax1.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())

ax1.set_title('Fourier Power Spectra')
ax1.set_xlabel('Estimated Rotational Period (hours)')

psList = abs(powerSpectrum).tolist()
psList.index(max(psList[start:end]))
# Out:
# 210

# %%
def getPeak(fftInput, start, interval, correctNum):
    errorArray = []
    tempMean = 0
    fftOutput = reset(fftInput)
    xRange = 1000
    correctDays = 0

    fftOutput = scenario4(fftOutput, interval)
    tempfft = fftOutput
    correctEstimate = 0
    for x in range(xRange):
        randomNum = random.random()*6
        fftOutput = tempfft
        powerSpectrum, frequency = findFourier(fftOutput[int(randomNum*360):int(randomNum*360 + 360)])

        psList = abs(powerSpectrum).tolist()
        estimated_days = psList.index(max(psList[start:]))
        errorArray.append(estimated_days)
        if estimated_days == correctNum:
            correctDays += 1
            
    return errorArray, correctDays

# %%
correctArray = []
xRange = 1000 #Number of random samples

samplingInterval = 18 #Sampling interval(hr)

for x in range(30):
    errorArray, correctDays = getPeak(annualArrayFUS, x, samplingInterval/2, 30) #(graph, start, interval, correctNum)    
    correctChance = correctDays/1000
    correctArray.append(correctChance)


plt.figure(figsize=(14,6))
plt.plot(correctArray)
plt.grid(True)
plt.ylabel('Probability of detecting diurnal cycle')
plt.xlabel('Fourier transform starting point')
plt.yticks(np.arange(0, 1.1, 0.1));

# %%
modeArray = []

samplingInterval = 36 #Sampling interval(hr)

for x in range(1, 35):
    errorArray, correctDays = getPeak(annualArrayFUS, x, samplingInterval/2, 30)
    modeArray.append(mode(errorArray))

plt.figure(figsize=(14,6))
plt.plot(modeArray)
plt.grid(True)
